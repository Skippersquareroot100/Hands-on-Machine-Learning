# %% [markdown]
# Pandas Library
# Useful for data processing & analysing
#
# Pandas Dataframe :
# Pandas Dataframe is two dimentional tabular data stuctured with labeled axes(row & column)

# %%
import pandas as pd
import numpy as np

# %%
#creating pandas dataframe
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()
print(housing)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
housing_df=pd.DataFrame(housing.data, columns=housing.feature_names)

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
housing_df.shape
# Out:
# (20640, 8)

# %%
type(housing)
# Out:
# sklearn.utils._bunch.Bunch

# %%
type(housing_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#importing data from a cvs file from local storage
diabetes_df=pd.read_csv('/Users/maruf/Downloads/diabetes.csv')
print("type:")
type(diabetes_df)
# Out:
# type:
# pandas.core.frame.DataFrame

# %%
#shape
diabetes_df.shape
# Out:
# (768, 9)

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %% [markdown]
# **Creating Random DataFram With Random Values by using Numpy**

# %%
random_df=pd.DataFrame(np.random.rand(20,10))

# %%
random_df.shape
# Out:
# (20, 10)

# %%
type(random_df)
# Out:
# pandas.core.frame.DataFrame

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.947001  0.744938  0.723095  0.160841  0.386490  0.149856  0.739232
# 1  0.655023  0.662982  0.379267  0.606872  0.670573  0.574575  0.044721
# 2  0.848826  0.498695  0.376588  0.698513  0.822985  0.466025  0.773911
# 3  0.231089  0.983428  0.278874  0.513393  0.441749  0.599739  0.865604
# 4  0.568349  0.021441  0.813125  0.493325  0.450700  0.952679  0.305276
#
#           7         8         9
# 0  0.738013  0.300177  0.644381
# 1  0.808706  0.394225  0.961470
# 2  0.686188  0.622150  0.036833
# 3  0.874378  0.703013  0.088539
# 4  0.785679  0.148960  0.886448

# %%
random_df.tail()
# Out:
#            0         1         2         3         4         5         6  \
# 15  0.951325  0.746891  0.365224  0.319824  0.457301  0.891149  0.846816
# 16  0.210414  0.146510  0.789188  0.571218  0.360562  0.199040  0.868954
# 17  0.236730  0.619700  0.723446  0.124619  0.879627  0.954854  0.067065
# 18  0.588509  0.289268  0.208920  0.522565  0.959939  0.656110  0.061203
# 19  0.495909  0.456906  0.003323  0.496907  0.282260  0.379654  0.992865
#
#            7         8         9
# 15  0.955324  0.930597  0.743360
# 16  0.968022  0.921568  0.529606
# 17  0.461281  0.559224  0.069097
# 18  0.869976  0.522193  0.740974
# 19  0.663880  0.827730  0.402890

# %%
random_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       20 non-null     float64
#  1   1       20 non-null     float64
#  2   2       20 non-null     float64
#  3   3       20 non-null     float64
#  4   4       20 non-null     float64
#  5   5       20 non-null     float64
#  6   6       20 non-null     float64
#  7   7       20 non-null     float64
#  8   8       20 non-null     float64
#  9   9       20 non-null     float64
# dtypes: float64(10)
# memory usage: 1.7 KB

# %%
housing_df.shape
# Out:
# (20640, 8)

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
#finding missing value
housing_df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#counting the values based on their data labels
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
#Group the Values based on their Mean
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
#All statistical values
housing_df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %%
#manipulation of dataframe
housing_df['Price']=housing.target
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
#removing a row
housing_df.drop(index=0,axis=0)#axis=0 for row
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
#removing column
housing_df.drop(columns='Latitude',axis=0)#axis=0 fro column
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Longitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556    -122.23
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842    -122.22
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260    -122.24
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945    -122.25
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467    -122.25
# ...       ...       ...       ...        ...         ...       ...        ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606    -121.09
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807    -121.21
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635    -121.22
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209    -121.32
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981    -121.24
#
#        Price
# 0      4.526
# ...

# %%
print('locting first column')
print(housing_df.iloc[:,0])
# Out:
# locting first column
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462
#           ...
# 20635    1.5603
# 20636    2.5568
# 20637    1.7000
# 20638    1.8672
# 20639    2.3886
# Name: MedInc, Length: 20640, dtype: float64
# locting second column
# 0        41.0
# 1        21.0
# 2        52.0
# 3        52.0
# 4        52.0
#          ...
# 20635    25.0
# 20636    18.0
# 20637    17.0
# 20638    18.0
# 20639    16.0
# Name: HouseAge, Length: 20640, dtype: float64
# locting third column
# 0        6.984127
# 1        6.238137
# 2        8.288136
# 3        5.817352
# 4        6.281853
#            ...
# 20635    5.045455
# 20636    6.114035
# 20637    5.205543
# 20638    5.329513
# 20639    5.254717
# Name: AveRooms, Length: 20640, dtype: float64
# locting fourth column
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# ...

# %%
print('locting second column')
print(housing_df.iloc[:,1])
# Out:
# locting second column
# 0        41.0
# 1        21.0
# 2        52.0
# 3        52.0
# 4        52.0
#          ...
# 20635    25.0
# 20636    18.0
# 20637    17.0
# 20638    18.0
# 20639    16.0
# Name: HouseAge, Length: 20640, dtype: float64

# %%
print('locting third column')
print(housing_df.iloc[:,2])
# Out:
# locting third column
# 0        6.984127
# 1        6.238137
# 2        8.288136
# 3        5.817352
# 4        6.281853
#            ...
# 20635    5.045455
# 20636    6.114035
# 20637    5.205543
# 20638    5.329513
# 20639    5.254717
# Name: AveRooms, Length: 20640, dtype: float64

# %%
print('locting fourth column')
print(housing_df.iloc[:,-1])
# Out:
# locting fourth column
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: Price, Length: 20640, dtype: float64

# %%
#correlatuion
housing_df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...
